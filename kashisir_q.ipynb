# %%
num =int(input())
if num>0:
    print(f'positive {num}')
elif num<0:
    print(f'negative {num}')
else:
    print(f'neutral {num}')
# Out:
# negative -67

# %%
num1= int(input())
num2=int(input())
num3=int(input())
if num1>num2>num3:
    print(f'num1: {num1}')
elif num2>num3>num1:
    print(f'num2: {num2}')
else :
    print(f'num3: {num3}')
# Out:
# num3: 344

# %%
num =int(input())
if num%3==0 and num%5==0:
    print('fizzbuzz')
elif num%3==0:
    print('fizz')
elif num%5==0:
    print('bizz')
# Out:
# bizz

# %%
num=int(input())
num1=int(input())
if num == num1:
    print('equal')
elif num > num1:
    print(f'{num} greater then {num1}')
elif num < num1 :
    print(f'{num1} greater then {num}')
# Out:
# equal

# %%
num =int(input())
if 0<=num<=9:
    print(f'its 1 dig {num}')
elif 10<=num<=99:
    print(f'its 2 dig {num}')
elif 100<=num<=999:
    print(f'its 3 dig {num}')
else:
    print('more then 3 digit')
# Out:
# its 3 dig 234

# %%
ch = input()
if len(ch)==1:
    ascii_no =ord(ch)
    if (65<=ascii_no<=90) or(97<=ascii_no<=122):
        print('alphabet',ch)
    elif 48<=ascii_no<=57:
        print('ascii value',ch)
    elif 32<=ascii_no<=126:
        print('special char',ch)
    else:
        print('invalid')
else:
    print('invalid input')
# Out:
# invalid input

# %%
num = int(input())
if 1<=num <=5:
    if num ==1:
        print('one')
    elif num ==2:
        print('two')
    elif num==3:
        print('three')
    elif num==4:
        print('four')
    elif num==5:
        print('five')
else:
    print('number is greater then 5')
# Out:
# number is greater then 5

# %%
ch =input()
if 'A'<=ch<='Z':
    print(f'uppercase {ch}')
elif 'a'<=ch<='z':
    print(f'lowercase {ch}')
elif '0'<=ch<='9':
    print('number',ch)
else:
    print('special symbol',ch)
# Out:
# special symbol $

# %%
ch =input()
if 'A'<=ch<='Z':
    res1=ord(ch)+32
    print(chr(res1))
elif 'a'<=ch<='z':
    res2=ord(ch)-32
    print(chr(res2))
else:
    res3 = ord(ch)-1
    res4 = ord(ch)+1

    print((chr(res3)) ,ch , (chr(res4)))
# Out:
# " # $

# %%
val=input()
if 'A'<=val<='Z':
    print('upper')
elif 'a'<=val<='z':
    print('lower')
elif '0'<=val<='9':
    print('number')
else :
    print('special char')
# Out:
# upper

# %%
per=int(input())
if 91<=per<=100:
    print('first class')
elif 61<=per<=90:
    print('second class')
elif 35<=per<=60:
    print('third class')
else:
    print('fail')
# Out:
# first class

# %%
char=eval(input())
if type(char)==list:
    mid = len(char)//2
    lis=input()
    char.insert(mid ,lis)
    print('updated list:',char)
elif type(char)==tuple:
    tup=input()
    print(tup + char)
elif type(char)==set:

# %%
cha = input()
if type(cha)==int:
    print(cha//5)
elif type(cha)==float:
    print(cha|15)
elif type(cha)==str:
    ch=cha[-1]
    print(ch+cha[:-1:])
else:
    print(list(cha))
# Out:
# 234.

# %%
ch=input()
if 'A'<=ch<='Z':
    res=ord(ch)+32
    rtt=chr(res+1)
    print(chr(res),rtt)
elif '0'<=(ch)<='9':
    res1=ord(ch)-6
    print(ch,res1)
else:
    print('invalid input')
# Out:
# v w

# %% [markdown]
# NESTED IF

# %%
ch = int(input())
if ch%2==0:
    if ch%4==0:
        print(ch*2)
if ch%2!=0:
    if ch%3==0 and ch%7==0:
        print((2*3.14)*ch)
# Out:
# 131.88

# %%
coll =list(input())
val = input()
if val in coll:
    if 'A'<=val<='Z':
        res=ord(val)+32
        print(chr(res))
    if 'a'<=val<='z':
        res2=ord(val)-32
        print(chr(res2))
else:
    print('invalid')
# Out:
# invalid

# %%
coll=str(input())
val=input()
if val in coll:
    if len(val)%2==0:
        print(coll[::2])
    else:
        print(coll[1::2])
else:
    print(coll)
# Out:
# elknha

# %%
cha= input()
if 'A'<=cha<='Z' or 'a'<=cha<='z':
    if 'A'<=cha<='Z':
        if cha in 'AEIOU':
            res=ord(cha)+1
            print(chr(res))
    if 'a'<=cha<='z':
        res1=ord(cha)-32
        print('uppercase',chr(res1))
elif '0'<=ch<='9' or 32<=ord(ch)<=47 or 58<=ord(ch)<=64 or 91<=ord(ch)<=96 or 123<=ord(ch)<=126:
    print(cha)
# Out:
# uppercase S
